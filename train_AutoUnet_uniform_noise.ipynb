# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
# %matplotlib inline
from PIL import Image
from dataset import *
from save_load import *
from NN_library.AutoUnet.AutoUnet_uniform import *
from NN_library.AutoUnet.train_AutoUnet_noise import *
# %load_ext autoreload
# %autoreload 2
# Out:
# Using device: cuda

# %%
data = dataset_uniform()
geometry, damage, imp_shrinkage, obs_shrinkage, stiffness = data.__getitem__(1000)
loaders = get_loaders(data, 16)

# %%
fig, axs = plt.subplots(nrows=4, ncols=11, figsize=(11, 4), dpi=200)
noise = 0.2*torch.rand_like(damage) - 0.1
for i in range(10):
    axs[0,i+1].imshow(geometry[0], cmap='Greys', vmin=0, vmax=1)
    axs[0,i+1].set_title(f't = {i+1}')
    axs[0,i+1].set_axis_off()
    axs[1,i+1].imshow(imp_shrinkage[i+1] / (-0.001), cmap='Greys', vmin=0, vmax=1)
    axs[1,i+1].set_axis_off()
    axs[2,i+1].imshow(damage[i], cmap='Greys')
    axs[2,i+1].set_axis_off()
    axs[3,i+1].imshow(torch.clamp(damage[i] + noise[i], 0., 1.), cmap='Greys', vmin=0, vmax=1)
    axs[3,i+1].set_axis_off()
axs[0,0].text(0.8, 0.05, 'geometry', rotation='vertical')
axs[0,0].set_axis_off()
axs[1,0].text(0.8, 0.35, 'load', rotation='vertical')
axs[1,0].set_axis_off()
axs[2,0].text(0.8, 0.2, 'damage', rotation='vertical')
axs[2,0].set_axis_off()
axs[3,0].text(0.8, 0.2, 'noisy dam.', rotation='vertical')
axs[3,0].set_axis_off()

# %%
name = 'NN_library/AutoUnet/AutoUnet_uniform_noise'
args = {'lr' : 0.0000001, 'epochs' : 20, 'dev' : dev, 'name' : name}

# %%
unet = AutoUNet()

# %%
torch.cuda.empty_cache()

# %%
total_params = sum(p.numel() for p in unet.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 7697345

# %%
unet = load_network(unet, args['name']+'_19', args)

# %%
losses_train, losses_val = train(unet, loaders, args)
# Out:
# Epoch: 0 batch: 0 mean train loss:  781.8478743543
# Epoch: 0 batch: 100 mean train loss:  642.4802704159
# Epoch: 0 batch: 200 mean train loss:  651.3345316948
# Epoch: 0 batch: 300 mean train loss:  652.8288639852
# Epoch: 0 batch: 400 mean train loss:  619.0291744226
# Epoch: 0 batch: 500 mean train loss:  881.1409381379
# Epoch: 0 batch: 600 mean train loss:  697.3136137202
# Epoch: 0 batch: 700 mean train loss:  736.3848468540
# Epoch: 0 mean train loss:  714.2558274560 mean val. rec. loss:  892.9296875000
# Epoch: 1 batch: 0 mean train loss:  559.7759319147
# Epoch: 1 batch: 100 mean train loss:  574.1051140058
# Epoch: 1 batch: 200 mean train loss:  861.8686301311
# Epoch: 1 batch: 300 mean train loss:  615.8522074931
# Epoch: 1 batch: 400 mean train loss:  661.0634290867
# Epoch: 1 batch: 500 mean train loss:  676.4455561438
# Epoch: 1 batch: 600 mean train loss:  690.4587667498
# Epoch: 1 batch: 700 mean train loss:  575.3227637499
# Epoch: 1 mean train loss:  705.6275839425 mean val. rec. loss:  881.5718994141
# Epoch: 2 batch: 0 mean train loss:  813.1879957950
# Epoch: 2 batch: 100 mean train loss:  542.8738614893
# Epoch: 2 batch: 200 mean train loss:  655.0725448722
# Epoch: 2 batch: 300 mean train loss:  924.7942748113
# Epoch: 2 batch: 400 mean train loss:  814.5052251838
# Epoch: 2 batch: 500 mean train loss:  627.7898662679
# Epoch: 2 batch: 600 mean train loss:  754.8349535082
# Epoch: 2 batch: 700 mean train loss:  781.0711590695
# Epoch: 15 batch: 300 mean train loss:  559.5245019828
# Epoch: 15 batch: 400 mean train loss:  780.3839783274
# Epoch: 15 batch: 500 mean train loss:  619.6711617547
# Epoch: 15 batch: 600 mean train loss:  727.5208606228
# Epoch: 15 batch: 700 mean train loss:  556.9117464055
# Epoch: 15 mean train loss:  700.7734309481 mean val. rec. loss:  883.0084838867
# Epoch: 16 batch: 0 mean train loss:  730.9165636450
# Epoch: 16 batch: 100 mean train loss:  526.7805963266
# Epoch: 16 batch: 200 mean train loss:  652.4131415563
# Epoch: 16 batch: 300 mean train loss:  563.5798674780
# Epoch: 16 batch: 400 mean train loss:  852.1315756326
# Epoch: 16 batch: 500 mean train loss:  804.2917006557
# Epoch: 16 batch: 600 mean train loss:  728.8231570273
# Epoch: 16 batch: 700 mean train loss:  620.8008755296
# Epoch: 16 mean train loss:  709.5269193348 mean val. rec. loss:  894.3994750977
# Epoch: 17 batch: 0 mean train loss:  622.2483355642
# Epoch: 17 batch: 100 mean train loss:  692.0562354136
# Epoch: 17 batch: 200 mean train loss:  1414.9993114846
# Epoch: 17 batch: 300 mean train loss:  595.3768460509
# Epoch: 17 batch: 400 mean train loss:  769.2243352298
# Epoch: 17 batch: 500 mean train loss:  567.1672752670
# Epoch: 17 batch: 600 mean train loss:  567.5486539598
# Epoch: 17 batch: 700 mean train loss:  713.4227070556
# Epoch: 17 mean train loss:  705.9806403258 mean val. rec. loss:  870.5442504883
# Epoch: 18 batch: 0 mean train loss:  837.8816262074
# Epoch: 18 batch: 100 mean train loss:  506.7552722177
# Epoch: 18 batch: 200 mean train loss:  1020.3082005198
# Epoch: 18 batch: 300 mean train loss:  544.9638129753
# Epoch: 18 batch: 400 mean train loss:  846.6665725770
# Epoch: 18 batch: 500 mean train loss:  923.7894979565
# Epoch: 18 batch: 600 mean train loss:  502.5016701321
# Epoch: 18 batch: 700 mean train loss:  889.3502233151
# Epoch: 18 mean train loss:  712.0139085337 mean val. rec. loss:  911.6421508789
# Epoch: 19 batch: 0 mean train loss:  619.0137655193
# Epoch: 19 batch: 100 mean train loss:  820.8362865698
# Epoch: 19 batch: 200 mean train loss:  719.3587805205
# Epoch: 19 batch: 300 mean train loss:  673.3907476802
# Epoch: 19 batch: 400 mean train loss:  683.5670930653
# Epoch: 19 batch: 500 mean train loss:  635.2380287769
# Epoch: 19 batch: 600 mean train loss:  608.2356286123
# Epoch: 19 batch: 700 mean train loss:  791.3515045047
# Epoch: 19 mean train loss:  706.1642119688 mean val. rec. loss:  885.0487670898

# %%
plt.plot(losses_train)
plt.plot(losses_val)
plt.xlabel('epoch')
plt.legend(['train', 'validation'])

# %% [markdown]
# ## Train with Convnet

# %%
from NN_library.ConvNet.ConvNet_uniform import *

name = 'NN_library/AutoUnet/AutoUnet_w_Conv_uniform'
conv_name = 'NN_library/ConvNet/Conv_w_AutoUnet_uniform'
# Out:
# Using device: cuda

# %%
args = {'lr' : 0.000001, 'epochs' : 20, 'dev' : dev, 'name' : name, 'conv_name' : conv_name}

# %%
unet = AutoUNet()
convnet = ConvNet(16)

# %%
convnet = load_network(convnet, 'NN_library/ConvNet/ConvNet_uniform', args)

# %%
unet = load_network(unet, 'NN_library/AutoUnet/AutoUnet_uniform', args)

# %%
losses_train, losses_val = train_w_Conv(unet, convnet, loaders, args)

# %%
plt.plot(losses_train)
plt.plot(losses_val)
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
