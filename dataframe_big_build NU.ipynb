# %%
import pandas as pd
import numpy as np
from dataset import *
from save_load import *
from NN_library.AutoUnet.AutoUnet import *
from NN_library.ConvNet.ConvNet import *
from NN_library.ConvNet.train_ConvNet import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
unet = AutoUNet()
convnet = ConvNet(16)

args = {'lr' : 0.001, 'epochs' : 20, 'dev' : dev, 'name' : 'NN_library/ConvNet/ConvNet'}
convnet = load_network(convnet, 'NN_library/ConvNet/ConvNet_49', args)
unet = load_network(unet, 'NN_library/AutoUnet/AutoUnet_49', args)  

unet.to(args['dev'])
convnet.to(args['dev'])
# Out:
# ConvNet(
#   (conv): Sequential(
#     (0): SpecialPad()
#     (1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ReLU()
#     (3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (4): SpecialPad()
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (6): ReLU()
#     (7): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (8): SpecialPad()
#     (9): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (10): ReLU()
#     (11): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (12): SpecialPad()
#     (13): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#     (14): ReLU()
#     (15): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (16): SpecialPad()
#     (17): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#     (18): ReLU()
#   )
#   (linear): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=9216, out_features=2, bias=True)
#     (2): Softplus(beta=1, threshold=20)
#   )
# )

# %%
data = dataset_big_nu()
loader = DataLoader(data, batch_size = 64, shuffle=False, num_workers=0)

# %%
total_damage = []
damage_profile = []
volume_profile = []
volume = []
stiffness_1 = []
stiffness_2 = []
stiffness = []
shrinkage = []

# %%
for i, (geometry, imp_shrinkage) in enumerate(loader):
    k = 0
    #k = 5*np.random.randint(0, 7)
    if k != 0:
        geometry[:,:,-k:] = 1
        geometry[:,:,-k-1:] = torch.where(geometry[:,:,-k-1:]==0, 0.5, geometry[:,:,-k-1:])
    geometry = geometry.to(args['dev'])
    imp_shrinkage = imp_shrinkage.to(args['dev']) / -0.001
    for n in range(10):
        if n == 0:
            x = torch.cat([geometry, imp_shrinkage[:,[1],:,:], imp_shrinkage[:,[0],:,:]], axis=1)
        else:
            x = torch.cat([geometry, imp_shrinkage[:,[n+1],:,:], y.detach()], axis=1)
        y = unet(x)
        x_shr = torch.cat([geometry, imp_shrinkage[:,[n+1],:,:], y.detach()], axis=1)
        y_shr = convnet(x_shr)
        if n == 0:
            stiffness_1 += y_shr[:,0].tolist()
        if n == 9:
            stiffness_2 += y_shr[:,0].tolist()
            total_damage += (y.sum(axis=(1,2,3)) / 99**2).tolist()
            damage_profile += (y.sum(axis=(1,3)) / 99**2).tolist()
            volume_profile += (torch.where(geometry<1, 1, 0).sum(axis=(1,3)) / 99**2).tolist()
            stiffness += y_shr[:,0].tolist()
            shrinkage += y_shr[:,1].tolist()

# %%
plt.plot(y.sum(dim=-1).cpu().detach()[0,0])
plt.plot(torch.where(geometry<1, 1, 0).sum(dim=-1).cpu().detach()[0,0])

# %%
plt.imshow(geometry.cpu()[0,0])
plt.colorbar()

# %%
torch.cuda.empty_cache()

# %%
plt.imshow(y.detach().cpu()[0,0])

# %%
df = pd.read_pickle('microstucture_big_NU.pkl')
df.head()
# Out:
#       curve_n                                     curve_area  \
# 0  [1, 13, 0]  [105.80074636770647, 227.96328911964014, 0.0]
# 1   [4, 0, 0]                  [278.0806039902927, 0.0, 0.0]
# 2   [4, 0, 0]                   [313.421728531106, 0.0, 0.0]
# 3  [3, 10, 0]  [218.03944019512616, 173.47923426585353, 0.0]
# 4   [4, 5, 0]    [299.7357110559889, 69.95675483906378, 0.0]
#
#                                                sizes  \
# 0  {16: [[12.156105356917523, 10.623884723487098]...
# 1  {16: [[13.2100775605406, 8.901632629103986], [...
# 2  {16: [[14.478128114885118, 7.07690334800868], ...
# 3  {16: [[10.690182333262214, 9.950449294945646],...
# 4  {16: [[11.825311336277718, 7.229526295980998],...
#
#                                               ratios  \
# 0  {16: [1.1442241395977328], 8: [1.4751999563701...
# 1  {16: [1.4840061493158128, 1.1343764452308507, ...
# 2  {16: [2.045828154338015, 1.7307378409831589, 1...
# 3  {16: [1.0743416720581973, 1.5227016310172952, ...
# ...

# %%
df['stiffness_1'] = stiffness_1
df['stiffness_2'] = stiffness_2

# %%
df['stiffness_1'] = df['stiffness_1'] * 30000
df['stiffness_2'] = df['stiffness_2'] * 30000

# %%
df['damage'] = total_damage
df['damage_profile'] = damage_profile
df['volume_profile'] = volume_profile
df['shrinkage'] = shrinkage
df['stiffness_ratio'] = stiffness
df['shrinkage'] = df['shrinkage'] * (-0.001)

# %%
df.to_pickle('microstucture_big_NU.pkl')
